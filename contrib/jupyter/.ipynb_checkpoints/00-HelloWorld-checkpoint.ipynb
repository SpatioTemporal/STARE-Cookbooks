# %%
import pystare as ps

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import cartopy.crs as ccrs

# %%
def add_coastlines(figax):
    figax[1].set_global()
    figax[1].costlines()
    return figax

def hello_plot(figax=None,spatial_index_values=None,plot_options=(None,None,),show=True):

    if figax is None:
        fig,ax = plt.subplots(subplot_kw=plot_options)
    
    if spatial_index_values is not None:
        lons,lats,intmat = ps.triangulate_indices(spatial_index_values)
        siv_triang = tri.Triangulation(lons,lats,intmat)
        print('si: ',siv)
        print('ax: ',ax)
        print('st: ',siv_triang)
        figax[1].triplot(siv_triang,transform=plot_options[1])
    
    if show:
        plt.show()
        
    return figax

# %%
# Set up the projection and transformation
proj         = ccrs.PlateCarree()
# proj        = ccrs.Robinson() # Drives matplotlib bug.
# proj        = ccrs.Mollweide() # Drives matplotlib bug.
transf       = ccrs.Geodetic()
plot_options = {'projection':projection,'transform':transform}

# %%
siv = 0 # STARE Spatial Index Value

hello_plot([siv],projection=proj,transform=transf)
# Out:
# si:  0
# ax:  < GeoAxes: <cartopy.crs.PlateCarree object at 0x120a1b770> >
# st:  <matplotlib.tri.triangulation.Triangulation object at 0x124ad5e90>
# (<Figure size 432x288 with 1 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x124a5b290>)

# %%
level_zero_increment = 1 << 59
fig,ax = plt.subplots(subplot_kw={'projection':proj,'transform':transf})
# fig,ax = hello_plot(projection=proj,transform=transf)
siv = 0
print('ax0: ',ax)
# hello_plot([siv],figax=None,projection=proj,transform=transf,show=True)
fig1,ax1 = hello_plot([siv],figax=(fig,ax,),projection=proj,transform=transf,show=True)
print('ax1: ',ax1)
# plt.show()

#for siv in range(0,8*level_zero_increment,level_zero_increment):
#    print(hex(siv))
#    hello_plot([siv],ax=ax,projection=proj,transform=transf,figure=False,show=False)
#plt.show()
# Out:
# ax0:  < GeoAxes: <cartopy.crs.PlateCarree object at 0x120a1b770> >
# si:  0
# ax:  < GeoAxes: <cartopy.crs.PlateCarree object at 0x120a1b770> >
# st:  <matplotlib.tri.triangulation.Triangulation object at 0x124aef8d0>
# ax1:  < GeoAxes: <cartopy.crs.PlateCarree object at 0x120a1b770> >
